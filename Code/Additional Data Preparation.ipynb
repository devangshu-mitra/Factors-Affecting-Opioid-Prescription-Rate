# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('opioids_dataset_edited.csv')

# %%
df
# Out:
#         Prscrbr_NPI Prscrbr_State_Abrvtn  \
# 0        1003070194                   WV
# 1        1003076928                   PA
# 2        1003146226                   LA
# 3        1003218074                   NY
# 4        1003388323                   MA
# ...             ...                  ...
# 305483   1326440124                   CA
# 305484   1326440124                   CA
# 305485   1326440223                   WA
# 305486   1326440223                   WA
# 305487   1326440223                   WA
#
#                                 Prscrbr_Type  Tot_Clms  Tot_30day_Fills  \
# 0                    Obstetrics & Gynecology        89             89.0
# 1                            Family Practice        39             39.0
# 2                         Nurse Practitioner        56             56.0
# 3                         Nurse Practitioner        57             57.0
# 4                         Nurse Practitioner        48             48.0
# ...

# %%
df = df.groupby(['Prscrbr_NPI', 'Prscrbr_State_Abrvtn', 'Prscrbr_Type']).sum()

# %%
df
# Out:
#                                                       Tot_Clms  \
# Prscrbr_NPI Prscrbr_State_Abrvtn Prscrbr_Type
# 1003000142  OH                   Anesthesiology            719
# 1003000522  FL                   Family Practice            47
# 1003000530  PA                   Internal Medicine          78
# 1003000597  OK                   Urology                   159
# 1003000902  KY                   Family Practice           119
# ...                                                        ...
# 1992992952  UT                   Physician Assistant      1019
# 1992994776  ID                   Physician Assistant       409
# 1992996912  NY                   Nurse Practitioner        271
# 1992997647  MI                   Family Practice           488
# 1992999122  FL                   Internal Medicine          18
#
#                                                       Tot_30day_Fills  \
# Prscrbr_NPI Prscrbr_State_Abrvtn Prscrbr_Type
# ...

# %%
df = df.reset_index()

# %%
# assuming your dataframe is named df
df['GE65_Tot_Drug_Cst'] = np.log1p(df['GE65_Tot_Drug_Cst'])
df['GE65_Tot_Day_Suply'] = np.log1p(df['GE65_Tot_Day_Suply'])

print(df)
# Out:
#         Prscrbr_NPI Prscrbr_State_Abrvtn         Prscrbr_Type  Tot_Clms  \
# 0        1003000142                   OH       Anesthesiology       719
# 1        1003000522                   FL      Family Practice        47
# 2        1003000530                   PA    Internal Medicine        78
# 3        1003000597                   OK              Urology       159
# 4        1003000902                   KY      Family Practice       119
# ...             ...                  ...                  ...       ...
# 155915   1992992952                   UT  Physician Assistant      1019
# 155916   1992994776                   ID  Physician Assistant       409
# 155917   1992996912                   NY   Nurse Practitioner       271
# 155918   1992997647                   MI      Family Practice       488
# 155919   1992999122                   FL    Internal Medicine        18
#
#         Tot_30day_Fills  Tot_Day_Suply  Tot_Drug_Cst  Tot_Benes  \
# ...

# %%
df
# Out:
#         Prscrbr_NPI Prscrbr_State_Abrvtn         Prscrbr_Type  Tot_Clms  \
# 0        1003000142                   OH       Anesthesiology       719
# 1        1003000522                   FL      Family Practice        47
# 2        1003000530                   PA    Internal Medicine        78
# 3        1003000597                   OK              Urology       159
# 4        1003000902                   KY      Family Practice       119
# ...             ...                  ...                  ...       ...
# 155915   1992992952                   UT  Physician Assistant      1019
# 155916   1992994776                   ID  Physician Assistant       409
# 155917   1992996912                   NY   Nurse Practitioner       271
# 155918   1992997647                   MI      Family Practice       488
# 155919   1992999122                   FL    Internal Medicine        18
#
#         Tot_30day_Fills  Tot_Day_Suply  Tot_Drug_Cst  Tot_Benes  \
# ...

# %%
data=pd.read_csv('calc_dataset.csv')

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Define the classification groups
classification_groups = {
    'Primary Care': ['Family Practice', 'Internal Medicine', 'Pediatric Medicine', 'General Practice', 'Family Medicine'],
    'Specialty Care': ['Obstetrics & Gynecology', 'Optometry' , 'Clinical Neuropsychologist', 'Psychiatry', 'Neurology', 'Psychiatry & Neurology', 'Medical Genetics and Genomics', 'Physical Medicine and Rehabilitation', 'Nephrology', 'Infectious Disease', 'Anesthesiology', 'Interventional Pain Management', 'Sleep Medicine', 'Urology', 'Maxillofacial Surgery', 'Rheumatology', 'Osteopathic Manipulative Medicine', 'Geriatric Medicine', 'Cardiology', 'Thoracic Surgery', 'Pulmonary Disease', 'Gastroenterology', 'Medical Oncology', 'Vascular Surgery', 'Hospice and Palliative Care', 'Plastic Surgery', 'Allergy/ Immunology', 'Sports Medicine', 'Podiatry', 'Plastic and Reconstructive Surgery', 'Ophthalmology', 'Clinical Cardiac Electrophysiology', 'Dermatology', 'Pain Medicine', 'Hand Surgery', 'Endocrinology', 'Radiation Oncology', 'Interventional Cardiology', 'Colorectal Surgery (Proctology)', 'Cardiac Surgery', 'Surgical Oncology', 'Neurosurgery', 'Gynecological Oncology', 'Thoracic Surgery (Cardiothoracic Vascular Surgery)', 'Interventional Radiology', 'Micrographic Dermatologic Surgery', 'Neurological Surgery', 'Geriatric Psychiatry', 'Legal Medicine', 'Undersea and Hyperbaric Medicine', 'Hematopoietic Cell Transplantation and Cellular Therapy', 'Advanced Heart Failure and Transplant Cardiology', 'Psychoanalyst', 'Independent Medical Examiner'],
    'Nursing': ['Nurse Practitioner', 'Certified Clinical Nurse Specialist', 'Certified Nurse Midwife', 'Registered Nurse', 'Certified Registered Nurse Anesthetist (CRNA)', 'Licensed Practical Nurse'],
    'Other Healthcare': ['Physician Assistant', 'Behavior Analyst',  'Marriage & Family Therapist', 'Pharmacist', 'Student in an Organized Health Care Education/Training Program', 'Diagnostic Radiology', 'Peripheral Vascular Disease', 'Nuclear Medicine', 'Physical Therapist in Private Practice', 'Neuromusculoskeletal Medicine, Sports Medicine', 'Chiropractic', 'Dental Assistant', 'Counselor', 'Naturopath', 'Colon & Rectal Surgery', 'Psychologist, Clinical', 'Psychologist', 'Emergency Medical Technician, Basic'],
    'Unknown': ['Undefined Physician type', 'Unknown Supplier/Provider Specialty'],
    'Clinic/Center': ['Clinic/Center', 'Clinic or Group Practice', 'Health Maintenance Organization'],
    'Emergency Medicine': ['Emergency Medicine', 'Ambulatory Surgical Center'],
    'Hospitalist': ['Hospitalist'],
    'Other': ['Specialist','Social Worker']
}

# Create a function to assign each specialty to a classification group
def assign_classification(specialty):
    for group, specialties in classification_groups.items():
        if specialty in specialties:
            return group
    return 'Unknown'

# Apply the function to the 'Prscrbr_Type' column to create a new column 'Classification'
data['Classification'] = data['Prscrbr_Type'].apply(assign_classification)

# %%
# Use LabelEncoder to convert the 'Classification' column to numeric values
le = LabelEncoder()
data['Classification_Encoded'] = le.fit_transform(data['Classification'])

# Print the first 5 rows of the data with the new columns
print(data.head())
# Out:
#    Prscrbr_NPI Prscrbr_State_Abrvtn             Prscrbr_Type    op_2020  \
# 0   1003007477                   MA       Nurse Practitioner   5.786047
# 1   1003070194                   WV  Obstetrics & Gynecology  37.028825
# 2   1003071499                   OR       Nurse Practitioner   3.382950
# 3   1003075516                   PA               Psychiatry   4.961779
# 4   1003076928                   PA          Family Practice  51.685393
#
#    medianop_2020  label_2020  Classification  Classification_Encoded
# 0       8.523592           0         Nursing                       3
# 1      18.085106           1  Specialty Care                       7
# 2       7.782686           0         Nursing                       3
# 3       2.543620           1  Specialty Care                       7
# 4       2.285799           1    Primary Care                       6

# %%
# Save the filtered dataset to a new CSV file
data.to_csv('calc_new_dataset.csv', index=False)

# %%
data2 = pd.read_csv('state_policies.csv')

# %%
data3 = pd.read_csv('calc_new_dataset.csv')

# %%
data5 = pd.merge(data3, data2, on='Prscrbr_State_Abrvtn', how='left')
data5
# Out:
#         Prscrbr_NPI Prscrbr_State_Abrvtn             Prscrbr_Type     op_2020  \
# 0        1003007477                   MA       Nurse Practitioner    5.786047
# 1        1003070194                   WV  Obstetrics & Gynecology   37.028825
# 2        1003071499                   OR       Nurse Practitioner    3.382950
# 3        1003075516                   PA               Psychiatry    4.961779
# 4        1003076928                   PA          Family Practice   51.685393
# ...             ...                  ...                      ...         ...
# 155915   1326434994                   IL        Internal Medicine   17.857143
# 155916   1326437153                   NC      Physician Assistant  100.000000
# 155917   1326438052                   WA       Emergency Medicine   21.311475
# 155918   1326439498                   CA       Nurse Practitioner   19.402985
# 155919   1326439548                   NV       Nurse Practitioner   45.833333
#
# ...

# %%
# Save the filtered dataset to a new CSV file
data5.to_csv('enc_dataset.csv')

# %%
df1= pd.read_csv('enc_dataset.csv')

# %%
df1
# Out:
#         Unnamed: 0  Prscrbr_NPI Prscrbr_State_Abrvtn             Prscrbr_Type  \
# 0                0   1003007477                   MA       Nurse Practitioner
# 1                1   1003070194                   WV  Obstetrics & Gynecology
# 2                2   1003071499                   OR       Nurse Practitioner
# 3                3   1003075516                   PA               Psychiatry
# 4                4   1003076928                   PA          Family Practice
# ...            ...          ...                  ...                      ...
# 155915      155915   1326434994                   IL        Internal Medicine
# 155916      155916   1326437153                   NC      Physician Assistant
# 155917      155917   1326438052                   WA       Emergency Medicine
# 155918      155918   1326439498                   CA       Nurse Practitioner
# 155919      155919   1326439548                   NV       Nurse Practitioner
#
# ...

# %%
df2=pd.read_csv('calc_new_dataset1.csv')

# %%
df2
# Out:
#         Prscrbr_NPI     op_2020  medianop_2020  label_2020  \
# 0        1003007477    5.786047       8.523592           0
# 1        1003070194   37.028825      18.085106           1
# 2        1003071499    3.382950       7.782686           0
# 3        1003075516    4.961779       2.543620           1
# 4        1003076928   51.685393       2.285799           1
# ...             ...         ...            ...         ...
# 155915   1326434994   17.857143       2.739726           1
# 155916   1326437153  100.000000      30.491640           1
# 155917   1326438052   21.311475      40.000000           0
# 155918   1326439498   19.402985      12.962963           1
# 155919   1326439548   45.833333      10.850826           1
#
#         Classification_Encoded
# 0                            3
# 1                            7
# 2                            3
# 3                            7
# 4                            6
# ...                        ...
# ...

# %%
new_df= pd.merge(df, df2, on='Prscrbr_NPI')

# %%
new_df
# Out:
#         Prscrbr_NPI Prscrbr_State_Abrvtn         Prscrbr_Type  Tot_Clms  \
# 0        1003000142                   OH       Anesthesiology       719
# 1        1003000522                   FL      Family Practice        47
# 2        1003000530                   PA    Internal Medicine        78
# 3        1003000597                   OK              Urology       159
# 4        1003000902                   KY      Family Practice       119
# ...             ...                  ...                  ...       ...
# 155915   1992992952                   UT  Physician Assistant      1019
# 155916   1992994776                   ID  Physician Assistant       409
# 155917   1992996912                   NY   Nurse Practitioner       271
# 155918   1992997647                   MI      Family Practice       488
# 155919   1992999122                   FL    Internal Medicine        18
#
#         Tot_30day_Fills  Tot_Day_Suply  Tot_Drug_Cst  Tot_Benes  \
# ...

# %%
new_df.to_csv('Model.csv', index=False)

# %%
df3=pd.read_csv('state_policies.csv')

# %%
df3
# Out:
#    Prscrbr_State_Abrvtn  Prescriber_Education  Day_Supply_Limitation_II  \
# 0                    AA                     0                         0
# 1                    AE                     0                         0
# 2                    AK                     0                         0
# 3                    AL                     1                         0
# 4                    AP                     0                         0
# 5                    AR                     0                         0
# 6                    AZ                     1                         0
# 7                    CA                     1                         0
# 8                    CO                     0                         0
# 9                    CT                     1                         0
# 10                   DC                     1                         0
# 11                   DE                     0                         1
# ...

# %%
model2= pd.merge(new_df, df3, on='Prscrbr_State_Abrvtn')

# %%
model2
# Out:
#         Prscrbr_NPI Prscrbr_State_Abrvtn         Prscrbr_Type  Tot_Clms  \
# 0        1003000142                   OH       Anesthesiology       719
# 1        1003005034                   OH   Nurse Practitioner        45
# 2        1003005729                   OH  Physician Assistant        29
# 3        1003011834                   OH   Emergency Medicine        11
# 4        1003013004                   OH      Family Practice        29
# ...             ...                  ...                  ...       ...
# 155915   1184736795                   AE  Physician Assistant        29
# 155916   1255484069                   AE    Internal Medicine        64
# 155917   1295706398                   AE  Physician Assistant        89
# 155918   1326139304                   AE   Emergency Medicine        45
# 155919   1821295528                   AE      Family Practice        35
#
#         Tot_30day_Fills  Tot_Day_Suply  Tot_Drug_Cst  Tot_Benes  \
# ...

# %%
model2.to_csv('Model2.csv', index=False)
